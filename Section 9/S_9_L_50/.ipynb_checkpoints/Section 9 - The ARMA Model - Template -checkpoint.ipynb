# %% [markdown]
# ## Importing the relevant packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.arima_model import ARMA
from scipy.stats.distributions import chi2 
import seaborn as sns
sns.set()

# %% [markdown]
# ## Importing the Data and Pre-processing

# %%
raw_csv_data = pd.read_csv("../../Index2018.csv") 
df_comp=raw_csv_data.copy()
df_comp.date = pd.to_datetime(df_comp.date, dayfirst = True)
df_comp.set_index("date", inplace=True)
df_comp=df_comp.asfreq('b')
df_comp=df_comp.fillna(method='ffill')

# %%
df_comp['market_value']=df_comp.ftse

# %%
del df_comp['spx']
del df_comp['dax']
del df_comp['ftse']
del df_comp['nikkei']
size = int(len(df_comp)*0.8)
df, df_test = df_comp.iloc[:size], df_comp.iloc[size:]

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## The LLR Test

# %%
def LLR_test(mod_1, mod_2, DF = 1):
    L1 = mod_1.fit().llf
    L2 = mod_2.fit().llf
    LR = (2*(L2-L1))    
    p = chi2.sf(LR, DF).round(3)
    return p

# %% [markdown]
# ## Creating Returns

# %%
df['returns'] = df.market_value.pct_change(1)*100
df.head()
# Out:
#             market_value   returns
# date
# 1994-01-07       3445.98       NaN
# 1994-01-10       3440.58 -0.156704
# 1994-01-11       3413.77 -0.779229
# 1994-01-12       3372.02 -1.222988
# 1994-01-13       3360.01 -0.356166

# %% [markdown]
# ## ARMA(1,1)

# %%
model_ret_ar_1_ma_1 = ARMA(df.returns[1:], order=(1,1))
results_ret_ar_1_ma_1 = model_ret_ar_1_ma_1.fit()
results_ret_ar_1_ma_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                     ARMA(1, 1)   Log Likelihood               -7916.500
# Method:                       css-mle   S.D. of innovations              1.171
# Date:                Wed, 28 Oct 2020   AIC                          15841.000
# Time:                        08:30:04   BIC                          15867.085
# Sample:                    01-10-1994   HQIC                         15850.140
#                          - 04-05-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0189      0.013      1.446      0.148      -0.007       0.045
# ar.L1.returns     0.7649      0.067     11.349      0.000       0.633       0.897
# ma.L1.returns    -0.8141      0.061    -13.406      0.000      -0.933      -0.695
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3074           +0.0000j            1.3074            0.0000
# MA.1            1.2284           +0.0000j            1.2284            0.0000
# -----------------------------------------------------------------------------
# """

# %%
model_ret_ar_1 = ARMA(df.returns[1:], order=(1,0))
model_ret_ma_1 = ARMA(df.returns[1:], order=(0,1))

# %%
print("\n ARMA vs AR ", LLR_test(model_ret_ar_1, model_ret_ar_1_ma_1))
print("\n ARMA vs MA ", LLR_test(model_ret_ma_1, model_ret_ar_1_ma_1))
# Out:
#  ARMA vs AR  0.0
#
#  ARMA vs MA  0.0

# %% [markdown]
# ## Higher-Lag ARMA Models

# %%
# ARMA(3,3)
model_ret_ar_3_ma_3 = ARMA(df.returns[1:], order=(3,3))
results_ret_ar_3_ma_3 = model_ret_ar_3_ma_3.fit()
results_ret_ar_3_ma_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                     ARMA(3, 3)   Log Likelihood               -7893.515
# Method:                       css-mle   S.D. of innovations              1.166
# Date:                Wed, 28 Oct 2020   AIC                          15803.030
# Time:                        08:30:08   BIC                          15855.199
# Sample:                    01-10-1994   HQIC                         15821.310
#                          - 04-05-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0189      0.014      1.395      0.163      -0.008       0.045
# ar.L1.returns    -0.1898      0.104     -1.827      0.068      -0.393       0.014
# ar.L2.returns    -0.2942      0.087     -3.389      0.001      -0.464      -0.124
# ar.L3.returns     0.4459      0.138      3.225      0.001       0.175       0.717
# ma.L1.returns     0.1707      0.099      1.726      0.084      -0.023       0.365
# ma.L2.returns     0.2277      0.084      2.701      0.007       0.062       0.393
# ma.L3.returns    -0.5432      0.127     -4.270      0.000      -0.793      -0.294
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.5168           -1.0283j            1.1508           -0.3241
# AR.2           -0.5168           +1.0283j            1.1508            0.3241
# AR.3            1.6932           -0.0000j            1.6932           -0.0000
# MA.1           -0.5286           -0.9835j            1.1166           -0.3285
# MA.2           -0.5286           +0.9835j            1.1166            0.3285
# MA.3            1.4764           -0.0000j            1.4764           -0.0000
# -----------------------------------------------------------------------------
# """

# %%
LLR_test(model_ret_ar_1_ma_1, model_ret_ar_3_ma_3, DF=4)
# Out:
# 0.0

# %%
# ARMA (3,2)
model_ret_ar_3_ma_2 = ARMA(df.returns[1:], order=(3,2))
results_ret_ar_3_ma_2 = model_ret_ar_3_ma_2.fit()
results_ret_ar_3_ma_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                     ARMA(3, 2)   Log Likelihood               -7895.747
# Method:                       css-mle   S.D. of innovations              1.166
# Date:                Wed, 28 Oct 2020   AIC                          15805.495
# Time:                        08:30:13   BIC                          15851.143
# Sample:                    01-10-1994   HQIC                         15821.491
#                          - 04-05-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0188      0.015      1.251      0.211      -0.011       0.048
# ar.L1.returns    -0.6785      0.087     -7.799      0.000      -0.849      -0.508
# ar.L2.returns    -0.5088      0.139     -3.670      0.000      -0.780      -0.237
# ar.L3.returns    -0.1141      0.015     -7.655      0.000      -0.143      -0.085
# ma.L1.returns     0.6568      0.087      7.536      0.000       0.486       0.828
# ma.L2.returns     0.4474      0.141      3.175      0.001       0.171       0.724
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.4929           -1.5101j            1.5885           -0.3002
# AR.2           -0.4929           +1.5101j            1.5885            0.3002
# AR.3           -3.4748           -0.0000j            3.4748           -0.5000
# MA.1           -0.7341           -1.3025j            1.4951           -0.3317
# MA.2           -0.7341           +1.3025j            1.4951            0.3317
# -----------------------------------------------------------------------------
# """

# %%
# ARMA (2,3)
model_ret_ar_2_ma_3 = ARMA(df.returns[1:], order=(2,3))
results_ret_ar_2_ma_3 = model_ret_ar_2_ma_3.fit()
results_ret_ar_2_ma_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                     ARMA(2, 3)   Log Likelihood               -7895.587
# Method:                       css-mle   S.D. of innovations              1.166
# Date:                Wed, 28 Oct 2020   AIC                          15805.174
# Time:                        08:30:14   BIC                          15850.823
# Sample:                    01-10-1994   HQIC                         15821.170
#                          - 04-05-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0189      0.015      1.276      0.202      -0.010       0.048
# ar.L1.returns    -0.5605      0.090     -6.245      0.000      -0.736      -0.385
# ar.L2.returns    -0.4187      0.193     -2.172      0.030      -0.796      -0.041
# ma.L1.returns     0.5378      0.090      6.000      0.000       0.362       0.714
# ma.L2.returns     0.3540      0.195      1.818      0.069      -0.028       0.736
# ma.L3.returns    -0.1158      0.016     -7.369      0.000      -0.147      -0.085
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.6694           -1.3930j            1.5455           -0.3213
# AR.2           -0.6694           +1.3930j            1.5455            0.3213
# MA.1           -0.7270           -1.1772j            1.3836           -0.3381
# MA.2           -0.7270           +1.1772j            1.3836            0.3381
# MA.3            4.5096           -0.0000j            4.5096           -0.0000
# -----------------------------------------------------------------------------
# """

# %%
LLR_test(model_ret_ar_2_ma_3, model_ret_ar_3_ma_3)
# Out:
# 0.042

# %%
# ARMA (3,1)
model_ret_ar_3_ma_1 = ARMA(df.returns[1:], order=(3,1))
results_ret_ar_3_ma_1 = model_ret_ar_3_ma_1.fit()
results_ret_ar_3_ma_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                     ARMA(3, 1)   Log Likelihood               -7899.072
# Method:                       css-mle   S.D. of innovations              1.167
# Date:                Wed, 28 Oct 2020   AIC                          15810.144
# Time:                        08:30:18   BIC                          15849.271
# Sample:                    01-10-1994   HQIC                         15823.855
#                          - 04-05-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0189      0.015      1.298      0.194      -0.010       0.047
# ar.L1.returns    -0.5077      0.088     -5.769      0.000      -0.680      -0.335
# ar.L2.returns    -0.0638      0.016     -4.023      0.000      -0.095      -0.033
# ar.L3.returns    -0.1102      0.014     -7.850      0.000      -0.138      -0.083
# ma.L1.returns     0.4839      0.088      5.500      0.000       0.311       0.656
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.5095           -0.0000j            1.5095           -0.5000
# AR.2            0.4653           -2.4076j            2.4521           -0.2196
# AR.3            0.4653           +2.4076j            2.4521            0.2196
# MA.1           -2.0668           +0.0000j            2.0668            0.5000
# -----------------------------------------------------------------------------
# """

# %%
LLR_test(model_ret_ar_3_ma_1, model_ret_ar_3_ma_2)
# Out:
# 0.01

# %%
# ARMA (2,2)
model_ret_ar_2_ma_2 = ARMA(df.returns[1:], order=(2,2))
results_ret_ar_2_ma_2 = model_ret_ar_2_ma_2.fit()
results_ret_ar_2_ma_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                     ARMA(2, 2)   Log Likelihood               -7913.223
# Method:                       css-mle   S.D. of innovations              1.170
# Date:                Wed, 28 Oct 2020   AIC                          15838.446
# Time:                        08:30:21   BIC                          15877.573
# Sample:                    01-10-1994   HQIC                         15852.156
#                          - 04-05-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0189      0.014      1.394      0.163      -0.008       0.045
# ar.L1.returns     0.7820      0.238      3.284      0.001       0.315       1.249
# ar.L2.returns    -0.1563      0.177     -0.884      0.377      -0.503       0.190
# ma.L1.returns    -0.8104      0.239     -3.388      0.001      -1.279      -0.342
# ma.L2.returns     0.1177      0.187      0.628      0.530      -0.250       0.485
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.5018           -0.3736j            2.5296           -0.0236
# AR.2            2.5018           +0.3736j            2.5296            0.0236
# MA.1            1.6107           +0.0000j            1.6107            0.0000
# MA.2            5.2744           +0.0000j            5.2744            0.0000
# -----------------------------------------------------------------------------
# """

# %%
# ARMA (1,3)
model_ret_ar_1_ma_3 = ARMA(df.returns[1:], order=(1,3))
results_ret_ar_1_ma_3 = model_ret_ar_1_ma_3.fit()
results_ret_ar_1_ma_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                     ARMA(1, 3)   Log Likelihood               -7896.838
# Method:                       css-mle   S.D. of innovations              1.167
# Date:                Wed, 28 Oct 2020   AIC                          15805.676
# Time:                        08:30:22   BIC                          15844.803
# Sample:                    01-10-1994   HQIC                         15819.386
#                          - 04-05-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0189      0.014      1.332      0.183      -0.009       0.047
# ar.L1.returns    -0.4699      0.096     -4.901      0.000      -0.658      -0.282
# ma.L1.returns     0.4474      0.095      4.691      0.000       0.260       0.634
# ma.L2.returns    -0.0637      0.015     -4.113      0.000      -0.094      -0.033
# ma.L3.returns    -0.1182      0.014     -8.200      0.000      -0.146      -0.090
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.1282           +0.0000j            2.1282            0.5000
# MA.1           -1.4882           -1.1206j            1.8629           -0.3973
# MA.2           -1.4882           +1.1206j            1.8629            0.3973
# MA.3            2.4376           -0.0000j            2.4376           -0.0000
# -----------------------------------------------------------------------------
# """

# %%
print("\n ARMA(3,2) \tLL = ", results_ret_ar_3_ma_2.llf, "\tAIC= ", results_ret_ar_3_ma_2.aic)
print("\n ARMA(1,3) \tLL = ", results_ret_ar_1_ma_3.llf, "\tAIC= ", results_ret_ar_1_ma_3.aic)
# Out:
#  ARMA(3,2) 	LL =  -7895.747458514923 	AIC=  15805.494917029846
#
#  ARMA(1,3) 	LL =  -7896.837893752985 	AIC=  15805.67578750597

# %% [markdown]
# ## Residuals for Returns

# %%
df['res_ret_ar_3_ma_2'] = results_ret_ar_3_ma_2.resid
df.head()
# Out:
#             market_value   returns  res_ret_ar_3_ma_2
# date
# 1994-01-07       3445.98       NaN                NaN
# 1994-01-10       3440.58 -0.156704          -0.175537
# 1994-01-11       3413.77 -0.779229          -0.802111
# 1994-01-12       3372.02 -1.222988          -1.269911
# 1994-01-13       3360.01 -0.356166          -0.463250

# %%
df.res_ret_ar_3_ma_2[1:].plot(figsize=(20,5))
plt.title("Residuals of Returns", size=20)
plt.show()

# %%
sgt.plot_acf(df.res_ret_ar_3_ma_2[1:], lags=40, zero=False)
plt.title("ACF for Residuals of Returns", size=20)
plt.show()

# %% [markdown]
# ## Reevaluating Model Selection

# %%
# ARMA (5,5)
model_ret_ar_5_ma_5 = ARMA(df.returns[1:], order=(5,5))
results_ret_ar_5_ma_5 = model_ret_ar_5_ma_5.fit()
results_ret_ar_5_ma_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                     ARMA(5, 5)   Log Likelihood               -7882.160
# Method:                       css-mle   S.D. of innovations              1.163
# Date:                Wed, 28 Oct 2020   AIC                          15788.321
# Time:                        08:30:31   BIC                          15866.575
# Sample:                    01-10-1994   HQIC                         15815.742
#                          - 04-05-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0189      0.013      1.402      0.161      -0.008       0.045
# ar.L1.returns    -0.0684      0.140     -0.490      0.624      -0.342       0.205
# ar.L2.returns    -0.6722      0.146     -4.603      0.000      -0.958      -0.386
# ar.L3.returns    -0.1152      0.141     -0.817      0.414      -0.392       0.161
# ar.L4.returns     0.1779      0.129      1.381      0.167      -0.075       0.430
# ar.L5.returns     0.1215      0.107      1.132      0.258      -0.089       0.332
# ma.L1.returns     0.0443      0.138      0.322      0.748      -0.226       0.314
# ma.L2.returns     0.6223      0.144      4.321      0.000       0.340       0.905
# ma.L3.returns     0.0107      0.136      0.079      0.937      -0.256       0.277
# ma.L4.returns    -0.1753      0.122     -1.436      0.151      -0.415       0.064
# ma.L5.returns    -0.2240      0.104     -2.148      0.032      -0.428      -0.020
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.0870           -1.0364j            1.0401           -0.2367
# AR.2            0.0870           +1.0364j            1.0401            0.2367
# AR.3            1.7715           -0.0000j            1.7715           -0.0000
# AR.4           -1.7050           -1.1784j            2.0726           -0.4038
# AR.5           -1.7050           +1.1784j            2.0726            0.4038
# MA.1            0.1033           -1.0434j            1.0485           -0.2343
# MA.2            0.1033           +1.0434j            1.0485            0.2343
# MA.3            1.4855           -0.0000j            1.4855           -0.0000
# MA.4           -1.2373           -1.0965j            1.6533           -0.3846
# MA.5           -1.2373           +1.0965j            1.6533            0.3846
# -----------------------------------------------------------------------------
# """

# %%
# ARMA (5,1)
model_ret_ar_5_ma_1 = ARMA(df.returns[1:], order=(5,1))
results_ret_ar_5_ma_1 = model_ret_ar_5_ma_1.fit()
results_ret_ar_5_ma_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                     ARMA(5, 1)   Log Likelihood               -7889.311
# Method:                       css-mle   S.D. of innovations              1.165
# Date:                Wed, 28 Oct 2020   AIC                          15794.623
# Time:                        08:30:34   BIC                          15846.792
# Sample:                    01-10-1994   HQIC                         15812.903
#                          - 04-05-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0189      0.013      1.407      0.159      -0.007       0.045
# ar.L1.returns     0.3440      0.131      2.624      0.009       0.087       0.601
# ar.L2.returns    -0.0458      0.015     -3.005      0.003      -0.076      -0.016
# ar.L3.returns    -0.0652      0.016     -4.010      0.000      -0.097      -0.033
# ar.L4.returns     0.0741      0.018      4.068      0.000       0.038       0.110
# ar.L5.returns    -0.0813      0.014     -5.688      0.000      -0.109      -0.053
# ma.L1.returns    -0.3673      0.131     -2.801      0.005      -0.624      -0.110
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.6158           -0.0000j            1.6158           -0.5000
# AR.2            1.3793           -0.8613j            1.6261           -0.0888
# AR.3            1.3793           +0.8613j            1.6261            0.0888
# AR.4           -0.1156           -1.6929j            1.6968           -0.2608
# AR.5           -0.1156           +1.6929j            1.6968            0.2608
# MA.1            2.7223           +0.0000j            2.7223            0.0000
# -----------------------------------------------------------------------------
# """

# %%
# ARMA (1,5)
model_ret_ar_1_ma_5 = ARMA(df.returns[1:], order=(1,5))
results_ret_ar_1_ma_5 = model_ret_ar_1_ma_5.fit()
results_ret_ar_1_ma_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5020
# Model:                     ARMA(1, 5)   Log Likelihood               -7890.973
# Method:                       css-mle   S.D. of innovations              1.165
# Date:                Wed, 28 Oct 2020   AIC                          15797.947
# Time:                        08:30:35   BIC                          15850.116
# Sample:                    01-10-1994   HQIC                         15816.228
#                          - 04-05-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0189      0.013      1.419      0.156      -0.007       0.045
# ar.L1.returns     0.3285      0.152      2.159      0.031       0.030       0.627
# ma.L1.returns    -0.3534      0.152     -2.332      0.020      -0.650      -0.056
# ma.L2.returns    -0.0404      0.015     -2.624      0.009      -0.071      -0.010
# ma.L3.returns    -0.0679      0.017     -4.022      0.000      -0.101      -0.035
# ma.L4.returns     0.0742      0.020      3.771      0.000       0.036       0.113
# ma.L5.returns    -0.0683      0.015     -4.660      0.000      -0.097      -0.040
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            3.0443           +0.0000j            3.0443            0.0000
# MA.1           -1.1897           -1.1548j            1.6580           -0.3774
# MA.2           -1.1897           +1.1548j            1.6580            0.3774
# MA.3            1.5041           -0.0000j            1.5041           -0.0000
# MA.4            0.9809           -1.6057j            1.8815           -0.1627
# MA.5            0.9809           +1.6057j            1.8815            0.1627
# -----------------------------------------------------------------------------
# """

# %%
print("\n ARMA(5,1) \tLL = ", results_ret_ar_5_ma_1.llf, "\tAIC= ", results_ret_ar_5_ma_1.aic)
print("\n ARMA(1,5) \tLL = ", results_ret_ar_1_ma_5.llf, "\tAIC= ", results_ret_ar_1_ma_5.aic)
# Out:
#  ARMA(5,1) 	LL =  -7889.3112829462225 	AIC=  15794.622565892445
#
#  ARMA(1,5) 	LL =  -7890.973460209503 	AIC=  15797.946920419006

# %%
print("\n ARMA(3,2) \tLL = ", results_ret_ar_3_ma_2.llf, "\tAIC= ", results_ret_ar_3_ma_2.aic)
# Out:
#  ARMA(3,2) 	LL =  -7895.747458514923 	AIC=  15805.494917029846

# %% [markdown]
# ## Residuals for the New Model

# %%
df['res_ret_ar_5_ma_1'] = results_ret_ar_5_ma_1.resid
df.head()
# Out:
#             market_value   returns  res_ret_ar_3_ma_2  res_ret_ar_5_ma_1
# date
# 1994-01-07       3445.98       NaN                NaN                NaN
# 1994-01-10       3440.58 -0.156704          -0.175537          -0.175617
# 1994-01-11       3413.77 -0.779229          -0.802111          -0.802191
# 1994-01-12       3372.02 -1.222988          -1.269911          -1.270020
# 1994-01-13       3360.01 -0.356166          -0.463250          -0.466056

# %%
sgt.plot_acf(df.res_ret_ar_5_ma_1[1:], lags=40, zero=False)
plt.title("ACF for Residuals of Returns", size=20)
plt.show()

# %% [markdown]
# ## ARMA Models for Prices

# %%
sgt.plot_acf(df.market_value, lags=40, zero=False)
plt.title("ACF for Prices", size=20)
plt.show()

# %%
sgt.plot_pacf(df.market_value, lags=40, zero=False)
plt.title("PACF for Prices", size=20)
plt.show()

# %%
model_ar_1_ma_1 = ARMA(df.market_value, order=(1,1))
results_ar_1_ma_1 = model_ar_1_ma_1.fit()
results_ar_1_ma_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           market_value   No. Observations:                 5021
# Model:                     ARMA(1, 1)   Log Likelihood              -27621.789
# Method:                       css-mle   S.D. of innovations             59.248
# Date:                Wed, 28 Oct 2020   AIC                          55251.579
# Time:                        08:40:09   BIC                          55277.664
# Sample:                    01-07-1994   HQIC                         55260.719
#                          - 04-05-2013
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5089.6414    496.782     10.245      0.000    4115.966    6063.317
# ar.L1.market_value     0.9985      0.001   1323.193      0.000       0.997       1.000
# ma.L1.market_value    -0.0190      0.015     -1.274      0.203      -0.048       0.010
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           +0.0000j            1.0015            0.0000
# MA.1           52.5209           +0.0000j           52.5209            0.0000
# -----------------------------------------------------------------------------
# """

# %%
df['res_ar_1_ma_1'] = results_ar_1_ma_1.resid

# %%
sgt.plot_acf(df.res_ar_1_ma_1, lags=40, zero=False)
plt.title("ACF for Residuals of Prices", size=20)
plt.show()

# %%
model_ar_6_ma_6 = ARMA(df.market_value, order=(6,6))
results_ar_6_ma_6 = model_ar_6_ma_6.fit(start_ar_lags=11)
results_ar_6_ma_6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           market_value   No. Observations:                 5021
# Model:                     ARMA(6, 6)   Log Likelihood              -27587.932
# Method:                       css-mle   S.D. of innovations             58.849
# Date:                Wed, 28 Oct 2020   AIC                          55203.864
# Time:                        08:44:52   BIC                          55295.164
# Sample:                    01-07-1994   HQIC                         55235.856
#                          - 04-05-2013
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5089.6491    568.204      8.957      0.000    3975.991    6203.308
# ar.L1.market_value     1.9275      0.032     59.933      0.000       1.865       1.991
# ar.L2.market_value    -1.7359      0.040    -43.375      0.000      -1.814      -1.657
# ar.L3.market_value     1.2677      0.034     36.802      0.000       1.200       1.335
# ar.L4.market_value    -0.2374      0.157     -1.509      0.131      -0.546       0.071
# ar.L5.market_value    -0.4062      0.165     -2.469      0.014      -0.729      -0.084
# ar.L6.market_value     0.1839      0.049      3.768      0.000       0.088       0.280
# ma.L1.market_value    -0.9486      0.035    -27.043      0.000      -1.017      -0.880
# ma.L2.market_value     0.7799      0.032     24.184      0.000       0.717       0.843
# ma.L3.market_value    -0.5084      0.031    -16.326      0.000      -0.569      -0.447
# ma.L4.market_value    -0.1561      0.158     -0.988      0.323      -0.466       0.154
# ma.L5.market_value     0.0952      0.057      1.680      0.093      -0.016       0.206
# ma.L6.market_value     0.0670      0.024      2.810      0.005       0.020       0.114
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.0857           -1.0502j            1.0537           -0.2370
# AR.2            0.0857           +1.0502j            1.0537            0.2370
# AR.3           -2.0257           -0.0000j            2.0257           -0.5000
# AR.4            1.0011           -0.0000j            1.0011           -0.0000
# AR.5            1.5307           -0.2670j            1.5538           -0.0275
# AR.6            1.5307           +0.2670j            1.5538            0.0275
# MA.1            0.1028           -1.0612j            1.0662           -0.2346
# MA.2            0.1028           +1.0612j            1.0662            0.2346
# MA.3            1.3623           -0.2795j            1.3907           -0.0322
# MA.4            1.3623           +0.2795j            1.3907            0.0322
# MA.5           -2.1754           -1.4338j            2.6054           -0.4073
# MA.6           -2.1754           +1.4338j            2.6054            0.4073
# -----------------------------------------------------------------------------
# """

# %%
model_ar_5_ma_6 = ARMA(df.market_value, order=(5,6))
results_ar_5_ma_6 = model_ar_5_ma_6.fit(start_ar_lags=1)
results_ar_5_ma_6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           market_value   No. Observations:                 5021
# Model:                     ARMA(5, 6)   Log Likelihood              -27587.863
# Method:                       css-mle   S.D. of innovations             58.849
# Date:                Wed, 28 Oct 2020   AIC                          55201.726
# Time:                        08:51:35   BIC                          55286.504
# Sample:                    01-07-1994   HQIC                         55231.433
#                          - 04-05-2013
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5089.6676    580.876      8.762      0.000    3951.171    6228.165
# ar.L1.market_value     1.3585      0.177      7.654      0.000       1.011       1.706
# ar.L2.market_value    -1.1290      0.237     -4.760      0.000      -1.594      -0.664
# ar.L3.market_value     0.9148      0.229      4.000      0.000       0.467       1.363
# ar.L4.market_value     0.0159      0.204      0.078      0.938      -0.383       0.415
# ar.L5.market_value    -0.1613      0.119     -1.352      0.176      -0.395       0.073
# ma.L1.market_value    -0.3796      0.178     -2.133      0.033      -0.728      -0.031
# ma.L2.market_value     0.7294      0.125      5.829      0.000       0.484       0.975
# ma.L3.market_value    -0.2198      0.153     -1.438      0.151      -0.519       0.080
# ma.L4.market_value    -0.1387      0.114     -1.215      0.224      -0.362       0.085
# ma.L5.market_value    -0.0879      0.017     -5.325      0.000      -0.120      -0.056
# ma.L6.market_value     0.0265      0.024      1.129      0.259      -0.020       0.073
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.0917           -1.0418j            1.0458           -0.2360
# AR.2            0.0917           +1.0418j            1.0458            0.2360
# AR.3            1.0010           -0.0000j            1.0010           -0.0000
# AR.4            1.8978           -0.0000j            1.8978           -0.0000
# AR.5           -2.9839           -0.0000j            2.9839           -0.5000
# MA.1            0.1071           -1.0487j            1.0542           -0.2338
# MA.2            0.1071           +1.0487j            1.0542            0.2338
# MA.3           -1.5353           -1.5156j            2.1574           -0.3760
# MA.4           -1.5353           +1.5156j            2.1574            0.3760
# MA.5            1.5918           -0.0000j            1.5918           -0.0000
# MA.6            4.5777           -0.0000j            4.5777           -0.0000
# -----------------------------------------------------------------------------
# """

# %%
model_ar_6_ma_5 = ARMA(df.market_value, order=(6,5))
results_ar_6_ma_5 = model_ar_6_ma_5.fit(start_ar_lags=7)
results_ar_6_ma_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           market_value   No. Observations:                 5021
# Model:                     ARMA(6, 5)   Log Likelihood              -27587.554
# Method:                       css-mle   S.D. of innovations             58.845
# Date:                Wed, 28 Oct 2020   AIC                          55201.108
# Time:                        08:53:00   BIC                          55285.886
# Sample:                    01-07-1994   HQIC                         55230.815
#                          - 04-05-2013
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5089.6450    582.593      8.736      0.000    3947.783    6231.507
# ar.L1.market_value     1.0214      0.147      6.936      0.000       0.733       1.310
# ar.L2.market_value    -0.8631      0.278     -3.110      0.002      -1.407      -0.319
# ar.L3.market_value     0.8673      0.445      1.951      0.051      -0.004       1.739
# ar.L4.market_value     0.0009      0.441      0.002      0.998      -0.864       0.866
# ar.L5.market_value     0.1387      0.414      0.335      0.738      -0.673       0.951
# ar.L6.market_value    -0.1669      0.200     -0.835      0.404      -0.559       0.225
# ma.L1.market_value    -0.0425      0.145     -0.293      0.770      -0.327       0.242
# ma.L2.market_value     0.7928      0.244      3.255      0.001       0.315       1.270
# ma.L3.market_value    -0.1183      0.234     -0.505      0.614      -0.578       0.341
# ma.L4.market_value    -0.0362      0.229     -0.158      0.875      -0.485       0.413
# ma.L5.market_value    -0.2545      0.196     -1.296      0.195      -0.639       0.130
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.0933           -1.0322j            1.0364           -0.2357
# AR.2            0.0933           +1.0322j            1.0364            0.2357
# AR.3           -1.0833           -1.3803j            1.7547           -0.3559
# AR.4           -1.0833           +1.3803j            1.7547            0.3559
# AR.5            1.0010           -0.0000j            1.0010           -0.0000
# AR.6            1.8103           -0.0000j            1.8103           -0.0000
# MA.1            0.1055           -1.0373j            1.0426           -0.2339
# MA.2            0.1055           +1.0373j            1.0426            0.2339
# MA.3            1.5359           -0.0000j            1.5359           -0.0000
# MA.4           -0.9445           -1.2089j            1.5341           -0.3556
# MA.5           -0.9445           +1.2089j            1.5341            0.3556
# -----------------------------------------------------------------------------
# """

# %%
model_ar_6_ma_3 = ARMA(df.market_value, order=(6,3))
results_ar_6_ma_3 = model_ar_6_ma_3.fit()
results_ar_6_ma_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           market_value   No. Observations:                 5021
# Model:                     ARMA(6, 3)   Log Likelihood              -27589.713
# Method:                       css-mle   S.D. of innovations             58.870
# Date:                Wed, 28 Oct 2020   AIC                          55201.426
# Time:                        08:53:45   BIC                          55273.161
# Sample:                    01-07-1994   HQIC                         55226.563
#                          - 04-05-2013
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5089.6102    556.450      9.147      0.000    3998.987    6180.233
# ar.L1.market_value     1.1140      0.236      4.716      0.000       0.651       1.577
# ar.L2.market_value    -1.0137      0.247     -4.110      0.000      -1.497      -0.530
# ar.L3.market_value     0.7515      0.236      3.183      0.001       0.289       1.214
# ar.L4.market_value     0.1432      0.217      0.660      0.509      -0.282       0.568
# ar.L5.market_value    -0.0877      0.024     -3.639      0.000      -0.135      -0.040
# ar.L6.market_value     0.0905      0.016      5.828      0.000       0.060       0.121
# ma.L1.market_value    -0.1347      0.237     -0.567      0.570      -0.600       0.330
# ma.L2.market_value     0.8552      0.064     13.378      0.000       0.730       0.981
# ma.L3.market_value     0.0618      0.214      0.289      0.773      -0.358       0.481
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0011           -0.0000j            1.0011           -0.0000
# AR.2            0.0955           -1.0587j            1.0629           -0.2357
# AR.3            0.0955           +1.0587j            1.0629            0.2357
# AR.4           -2.1294           -0.0000j            2.1294           -0.5000
# AR.5            0.9533           -1.9178j            2.1417           -0.1766
# AR.6            0.9533           +1.9178j            2.1417            0.1766
# MA.1            0.1182           -1.0657j            1.0722           -0.2324
# MA.2            0.1182           +1.0657j            1.0722            0.2324
# MA.3          -14.0817           -0.0000j           14.0817           -0.5000
# -----------------------------------------------------------------------------
# """

# %%
model_ar_6_ma_2 = ARMA(df.market_value, order=(6,2))
results_ar_6_ma_2 = model_ar_6_ma_2.fit()
results_ar_6_ma_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           market_value   No. Observations:                 5021
# Model:                     ARMA(6, 2)   Log Likelihood              -27589.750
# Method:                       css-mle   S.D. of innovations             58.871
# Date:                Wed, 28 Oct 2020   AIC                          55199.500
# Time:                        08:54:22   BIC                          55264.714
# Sample:                    01-07-1994   HQIC                         55222.352
#                          - 04-05-2013
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5089.6459    559.476      9.097      0.000    3993.093    6186.199
# ar.L1.market_value     1.1801      0.052     22.528      0.000       1.077       1.283
# ar.L2.market_value    -1.0823      0.075    -14.355      0.000      -1.230      -0.934
# ar.L3.market_value     0.8181      0.068     12.070      0.000       0.685       0.951
# ar.L4.market_value     0.0807      0.027      2.937      0.003       0.027       0.135
# ar.L5.market_value    -0.0879      0.025     -3.563      0.000      -0.136      -0.040
# ar.L6.market_value     0.0891      0.015      5.923      0.000       0.060       0.119
# ma.L1.market_value    -0.2013      0.051     -3.965      0.000      -0.301      -0.102
# ma.L2.market_value     0.8589      0.064     13.317      0.000       0.733       0.985
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0011           -0.0000j            1.0011           -0.0000
# AR.2            0.0927           -1.0633j            1.0673           -0.2362
# AR.3            0.0927           +1.0633j            1.0673            0.2362
# AR.4           -2.2407           -0.0000j            2.2407           -0.5000
# AR.5            1.0201           -1.8301j            2.0952           -0.1691
# AR.6            1.0201           +1.8301j            2.0952            0.1691
# MA.1            0.1172           -1.0726j            1.0790           -0.2327
# MA.2            0.1172           +1.0726j            1.0790            0.2327
# -----------------------------------------------------------------------------
# """

# %%
model_ar_6_ma_1 = ARMA(df.market_value, order=(6,1))
results_ar_6_ma_1 = model_ar_6_ma_1.fit()
results_ar_6_ma_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           market_value   No. Observations:                 5021
# Model:                     ARMA(6, 1)   Log Likelihood              -27594.195
# Method:                       css-mle   S.D. of innovations             58.923
# Date:                Wed, 28 Oct 2020   AIC                          55206.389
# Time:                        08:55:08   BIC                          55265.082
# Sample:                    01-07-1994   HQIC                         55226.956
#                          - 04-05-2013
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5089.6441    586.505      8.678      0.000    3940.116    6239.172
# ar.L1.market_value     1.3921      0.058     23.931      0.000       1.278       1.506
# ar.L2.market_value    -0.4369      0.059     -7.401      0.000      -0.553      -0.321
# ar.L3.market_value    -0.0101      0.025     -0.409      0.683      -0.059       0.038
# ar.L4.market_value     0.1126      0.025      4.527      0.000       0.064       0.161
# ar.L5.market_value    -0.1158      0.025     -4.717      0.000      -0.164      -0.068
# ar.L6.market_value     0.0573      0.014      4.067      0.000       0.030       0.085
# ma.L1.market_value    -0.4127      0.060     -6.925      0.000      -0.529      -0.296
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0010           -0.0000j            1.0010           -0.0000
# AR.2           -1.7608           -0.0000j            1.7608           -0.5000
# AR.3           -0.0803           -1.8407j            1.8425           -0.2569
# AR.4           -0.0803           +1.8407j            1.8425            0.2569
# AR.5            1.4694           -0.8691j            1.7072           -0.0850
# AR.6            1.4694           +0.8691j            1.7072            0.0850
# MA.1            2.4233           +0.0000j            2.4233            0.0000
# -----------------------------------------------------------------------------
# """

# %%
LLR_test(model_ar_6_ma_1, model_ar_6_ma_2)
# Out:
# 0.003

# %%
print("ARMA(5,6):  \t LL = ", results_ar_5_ma_6.llf, "\t AIC = ", results_ar_5_ma_6.aic)
print("ARMA(6,2):  \t LL = ", results_ar_6_ma_2.llf, "\t AIC = ", results_ar_6_ma_2.aic)
# Out:
# ARMA(5,6):  	 LL =  -27587.862952034102 	 AIC =  55201.725904068204
# ARMA(6,2):  	 LL =  -27589.750018670253 	 AIC =  55199.500037340506

# %%
print("ARMA(5,6):  \t LL = ", results_ar_5_ma_6.llf, "\t AIC = ", results_ar_5_ma_6.aic)
print("ARMA(6,1):  \t LL = ", results_ar_6_ma_1.llf, "\t AIC = ", results_ar_6_ma_1.aic)
# Out:
# ARMA(5,6):  	 LL =  -27587.862952034102 	 AIC =  55201.725904068204
# ARMA(6,1):  	 LL =  -27594.194571372387 	 AIC =  55206.389142744774

# %%
df['res_ar_5_ma_6'] = results_ar_5_ma_6.resid
sgt.plot_acf(df.res_ar_5_ma_6, lags=40, zero=False)
plt.title("ACF for Residuals of Prices", size=20)
plt.show()

# %%
df['res_ar_6_ma_2'] = results_ar_6_ma_2.resid
sgt.plot_acf(df.res_ar_6_ma_2, lags=40, zero=False)
plt.title("ACF for Residuals of Prices", size=20)
plt.show()

# %% [markdown]
# ## ARMA for Returns vs ARMA for Prices

# %%
print("ARMA(5,6) for Prices:  \t LL = ", results_ar_5_ma_6.llf, "\t AIC = ", results_ar_5_ma_6.aic)
print("ARMA(5,1) for Returns: \t LL = ", results_ret_ar_5_ma_1.llf, "\t AIC = ", results_ret_ar_5_ma_1.aic)
# Out:
# ARMA(5,6) for Prices:  	 LL =  -27587.862952034102 	 AIC =  55201.725904068204
# ARMA(5,1) for Returns: 	 LL =  -7889.3112829462225 	 AIC =  15794.622565892445
